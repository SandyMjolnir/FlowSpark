# %%
# %pip install -e "c:/Sandeep/VSCodeProjects/FlowSpark"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///C:/Sandeep/VSCodeProjects/FlowSpark
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: lxml>=4.9.0 in c:\users\258623\appdata\roaming\python\python313\site-packages (from flowspark==0.1.0) (6.0.2)
# Requirement already satisfied: jinja2>=3.1.0 in c:\users\258623\appdata\roaming\python\python313\site-packages (from flowspark==0.1.0) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\258623\appdata\roaming\python\python313\site-packages (from jinja2>=3.1.0->flowspark==0.1.0) (3.0.2)
# Building wheels for collected packages: flowspark
#   Building editable for flowspark (pyproject.toml): started
#   Building editable for flowspark (pyproject.toml): finished with status 'done'
#   Created wheel for flowspark: filename=flowspark-0.1.0-0.editable-py3-none-any.whl size=5833 sha256=8c45ba61b3de17078a0cd8a2d68dd54d9f65a49de648edd2bcb7f02fb03a8557
#   Stored in directory: C:\Users\258623\AppData\Local\Temp\pip-ephem-wheel-cache-6xjb2upu\wheels\6b\80\e7\85e8d2545fa636e15246a0fb18932208305fed2459ad18c50a
# Successfully built flowspark
# Installing collected packages: flowspark
#   Attempting uninstall: flowspark
#     Found existing installation: flowspark 0.1.0
#     Uninstalling flowspark-0.1.0:
#       Successfully uninstalled flowspark-0.1.0
# Successfully installed flowspark-0.1.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from flowspark import AlteryxParser, ToolMapper, NotebookGenerator, EffortEstimator

workflow = AlteryxParser().parse_file("Accident Workflow.yxmd")
mapped   = ToolMapper().map_workflow(workflow)
NotebookGenerator().generate(workflow, mapped, output_dir="output/")

report = EffortEstimator().estimate(workflow, mapped)
print(report.dashboard_text())
# Out:
# ============================================================
#   FlowSpark Effort Estimation Dashboard
#   Workflow: Accident Workflow
# ============================================================
#   Tool ID      Category              Hours  Bar
# ------------------------------------------------------------
#   1            InputData              0.5h  ██████████
#   2            Summarize              1.0h  ████████████████████
#   3            BrowseV2               2.0h  ████████████████████████████████████████ ⚠
#   4            BrowseV2               2.0h  ████████████████████████████████████████ ⚠
#   5            Filter                 0.5h  ██████████
#   7            BrowseV2               2.0h  ████████████████████████████████████████ ⚠
#   16           Formula                1.0h  ████████████████████
#   17                                  2.0h  ████████████████████████████████████████ ⚠
#   22                                  2.0h  ████████████████████████████████████████ ⚠
# ------------------------------------------------------------
#   TOTAL                               13.0h
#   Complexity: MEDIUM      Sprints: 0.3
# ============================================================
#
#   ℹ  5 tool(s) require manual migration – review ⚠️ items carefully before estimating further.
